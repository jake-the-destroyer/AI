# %% [markdown]
# <h1>Pandas!</h1>

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Series
s = pd.Series([2,4,-12,0,2])
s
# Out:
# 0     2
# 1     4
# 2   -12
# 3     0
# 4     2
# dtype: int64

# %%
#We can ask for the shape
s.shape
# Out:
# (5,)

# %%
#We can ask for the type
s.dtype
# Out:
# dtype('int64')

# %%
#We can ask for the values
s.values
# Out:
# array([  2,   4, -12,   0,   2])

# %%
#We can also ask for the index
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
#Once we know the index, we can index it! 
s[3]
# Out:
# 0

# %%
#We can slice it and it will behave pretty much as we have seen until now.
s[1:3]
# Out:
# 1     4
# 2   -12
# dtype: int64

# %%
#Similarly
s[1:]
# Out:
# 1     4
# 2   -12
# 3     0
# 4     2
# dtype: int64

# %%
#We can do the fancy indexing.... Here we're asking for things in positions 2, 1 & 3
s[[2,1,3]]
# Out:
# 2   -12
# 1     4
# 3     0
# dtype: int64

# %%
#As well as fancy indexing, we can do boolean indexing
s[[True, False, True, False, True]]
# Out:
# 0     2
# 2   -12
# 4     2
# dtype: int64

# %%
#We can assign using indexing and slicing as we have seen before.
s[2] = 100
s[3:5] = [4, 10]
s
# Out:
# 0      2
# 1      4
# 2    100
# 3      4
# 4     10
# dtype: int64

# %%
#We can broadcast with slicing.
s[1:3] = -200
s
# Out:
# 0      2
# 1   -200
# 2   -200
# 3      4
# 4     10
# dtype: int64

# %%
#We can do pretty much the same stuff we had with the numpy arrays.
s * 2
# Out:
# 0      4
# 1   -400
# 2   -400
# 3      8
# 4     20
# dtype: int64

# %%
#Or the positive and negative
s > 0
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4     True
# dtype: bool

# %%
#Some more boolean indexing
s[s > 0]
# Out:
# 0     2
# 3     4
# 4    10
# dtype: int64

# %%
#There aren't many functions in pandas, instead we have methods for all!
s.sum()
# Out:
# -384

# %%
s.mean()
# Out:
# -76.799999999999997

# %%
s.unique() #Returns a new series without any duplicates
# Out:
# array([   2, -200,    4,   10])

# %%
#Returns a series with the occurences of each element. 
#The index is now the value of the old series.
s.value_counts()
# Out:
# -200    2
#  4      1
#  10     1
#  2      1
# dtype: int64

# %%
#Methods for removing something using indexing....
s.drop(2)
# Out:
# 0      2
# 1   -200
# 3      4
# 4     10
# dtype: int64

# %%
#Dropping using fancy indexing.
s.drop([2,3])
# Out:
# 0      2
# 1   -200
# 4     10
# dtype: int64

# %%
#BUT... s hasn't actually changed, we just altered how it appeared for a minute.
s
# Out:
# 0      2
# 1   -200
# 2   -200
# 3      4
# 4     10
# dtype: int64

# %%
#If we really want to change it we can...
s.drop(3,inplace = True)
s
# Out:
# 0      2
# 1   -200
# 2   -200
# 4     10
# dtype: int64

# %%
#We can then reset the series such that the indexing is consecutive.
s.reset_index(drop = True, inplace = True)
s
# Out:
# 0      2
# 1   -200
# 2   -200
# 3     10
# dtype: int64

# %%
#This takes us on to the second data structire.. called a dataframe. It is 2D, like a table.
df = pd.DataFrame({'a' : [1,2,3], 'b' : [4,5,6], 'c' : [7,8,9]})
df
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
df = pd.read_csv('dataset-stop-and-searchA.csv')
df
# Out:
#     Gender      Age                                  Suspect-ethnicity  \
# 0     Male    18-24                                    Not Stated (NS)
# 1     Male    18-24                                    Not Stated (NS)
# 2     Male    10-17                         White - White British (W1)
# 3     Male    10-17                         White - White British (W1)
# 4     Male    10-17  Black or Black British - Any other Black ethni...
# 5     Male    10-17                         White - White British (W1)
# 6     Male    18-24     White - Any other White ethnic background (W9)
# 7     Male  over 34            Black or Black British - Caribbean (B1)
# 8     Male    18-24                         White - White British (W1)
# 9     Male    18-24                         White - White British (W1)
# 10    Male    10-17                         White - White British (W1)
# 11    Male  over 34                         White - White British (W1)
# 12    Male    10-17                         White - White British (W1)
# 13    Male    10-17                         White - White British (W1)
# 14    Male    10-17                         White - White British (W1)
# 15    Male    10-17                         White - White British (W1)
# 16    Male    10-17                         White - White British (W1)
# 17    Male    25-34                         White - White British (W1)
# 18    Male    10-17                         White - White British (W1)
# 19  Female  over 34                         White - White British (W1)
# 20    Male    25-34                         White - White British (W1)
# 21    Male    10-17            Black or Black British - Caribbean (B1)
# 22    Male    10-17                                                NaN
# 23    Male    25-34            Asian or Asian British - Pakistani (A2)
# 24    Male    18-24            Black or Black British - Caribbean (B1)
# 25    Male    18-24                         White - White British (W1)
# 26    Male    18-24                         White - White British (W1)
# 27    Male    18-24     White - Any other White ethnic background (W9)
# 28    Male    18-24                         White - White British (W1)
# 29    Male    18-24                         White - White British (W1)
# 30    Male    25-34                                                NaN
# 31    Male    18-24              Black or Black British - African (B2)
# 32    Male    18-24                         White - White British (W1)
# 33    Male    18-24            Asian or Asian British - Pakistani (A2)
# 34    Male    25-34                         White - White British (W1)
# 35    Male  over 34                         White - White British (W1)
# 36    Male    18-24                         White - White British (W1)
# 37    Male    10-17                         White - White British (W1)
# 38    Male  over 34                         White - White British (W1)
# 39    Male  over 34            Black or Black British - Caribbean (B1)
#
#    Officer-ethnicity          Object-of-search  \
# 0              Asian          Controlled drugs
# 1              Black          Controlled drugs
# 2              White              Stolen goods
# 3              White              Stolen goods
# 4              Black              Stolen goods
# 5              White              Stolen goods
# 6                NaN              Stolen goods
# 7              Black          Controlled drugs
# 8              White              Stolen goods
# 9              White  Article for use in theft
# 10             White         Offensive weapons
# 11             White          Controlled drugs
# 12             White          Controlled drugs
# 13             White          Controlled drugs
# 14             White          Controlled drugs
# 15             White              Stolen goods
# 16             White              Stolen goods
# 17             White          Controlled drugs
# 18             White          Controlled drugs
# 19             White              Stolen goods
# 20             White              Stolen goods
# 21             Black         Offensive weapons
# 22             Asian         Offensive weapons
# 23             Asian          Controlled drugs
# 24             Black          Controlled drugs
# 25             White          Controlled drugs
# 26             White          Controlled drugs
# 27             White          Controlled drugs
# 28             White              Stolen goods
# 29             White         Offensive weapons
# 30               NaN          Controlled drugs
# 31             Black          Controlled drugs
# 32             White          Controlled drugs
# 33             Asian         Offensive weapons
# 34             White          Controlled drugs
# 35             White              Stolen goods
# 36             White          Controlled drugs
# 37             White          Controlled drugs
# 38             White          Controlled drugs
# 39             Black              Stolen goods
#
#                                          Outcome
# 0              Nothing found - no further action
# 1              Nothing found - no further action
# 2              Nothing found - no further action
# 3              Nothing found - no further action
# 4              Nothing found - no further action
# 5              Nothing found - no further action
# 6                               Suspect arrested
# 7   Article found - Detailed outcome unavailable
# 8                               Suspect arrested
# 9                               Suspect arrested
# 10             Nothing found - no further action
# 11             Nothing found - no further action
# 12             Nothing found - no further action
# 13             Nothing found - no further action
# 14             Nothing found - no further action
# 15             Nothing found - no further action
# 16             Nothing found - no further action
# 17  Article found - Detailed outcome unavailable
# 18                              Suspect arrested
# 19                              Suspect arrested
# 20                              Suspect arrested
# 21             Nothing found - no further action
# 22             Nothing found - no further action
# 23             Nothing found - no further action
# 24  Article found - Detailed outcome unavailable
# 25             Nothing found - no further action
# 26             Nothing found - no further action
# 27             Nothing found - no further action
# 28                              Suspect arrested
# 29             Nothing found - no further action
# 30             Nothing found - no further action
# 31             Nothing found - no further action
# 32             Nothing found - no further action
# 33             Nothing found - no further action
# 34  Article found - Detailed outcome unavailable
# 35             Nothing found - no further action
# 36             Nothing found - no further action
# 37       Offender given drugs possession warning
# 38             Nothing found - no further action
# 39             Nothing found - no further action

# %%
#Here we can use a summary of the data.
df.describe(include = 'all')
# Out:
#        Gender    Age           Suspect-ethnicity Officer-ethnicity  \
# count      40     40                          38                38
# unique      2      4                           7                 3
# top      Male  18-24  White - White British (W1)             White
# freq       39     15                          26                27
#
#         Object-of-search                            Outcome
# count                 40                                 40
# unique                 4                                  4
# top     Controlled drugs  Nothing found - no further action
# freq                  21                                 28

# %%
#This will tell you the names of the columns
df.columns
# Out:
# Index(['Gender', 'Age', 'Suspect-ethnicity', 'Officer-ethnicity',
#        'Object-of-search', 'Outcome'],
#       dtype='object')

# %%
#And.. the names of the rows....
df.index
# Out:
# RangeIndex(start=0, stop=40, step=1)

# %%
#Or the shape...
df.shape
# Out:
# (40, 6)

# %%
df.dtypes
# Out:
# Gender               object
# Age                  object
# Suspect-ethnicity    object
# Officer-ethnicity    object
# Object-of-search     object
# Outcome              object
# dtype: object

# %%
#Below, we are extracting one column and we are outputting a series
df['Suspect-ethnicity']
# Out:
# 0                                       Not Stated (NS)
# 1                                       Not Stated (NS)
# 2                            White - White British (W1)
# 3                            White - White British (W1)
# 4     Black or Black British - Any other Black ethni...
# 5                            White - White British (W1)
# 6        White - Any other White ethnic background (W9)
# 7               Black or Black British - Caribbean (B1)
# 8                            White - White British (W1)
# 9                            White - White British (W1)
# 10                           White - White British (W1)
# 11                           White - White British (W1)
# 12                           White - White British (W1)
# 13                           White - White British (W1)
# 14                           White - White British (W1)
# 15                           White - White British (W1)
# 16                           White - White British (W1)
# 17                           White - White British (W1)
# 18                           White - White British (W1)
# 19                           White - White British (W1)
# 20                           White - White British (W1)
# 21              Black or Black British - Caribbean (B1)
# 22                                                  NaN
# 23              Asian or Asian British - Pakistani (A2)
# 24              Black or Black British - Caribbean (B1)
# 25                           White - White British (W1)
# 26                           White - White British (W1)
# 27       White - Any other White ethnic background (W9)
# 28                           White - White British (W1)
# 29                           White - White British (W1)
# 30                                                  NaN
# 31                Black or Black British - African (B2)
# 32                           White - White British (W1)
# 33              Asian or Asian British - Pakistani (A2)
# 34                           White - White British (W1)
# 35                           White - White British (W1)
# 36                           White - White British (W1)
# 37                           White - White British (W1)
# 38                           White - White British (W1)
# 39              Black or Black British - Caribbean (B1)
# Name: Suspect-ethnicity, dtype: object

# %%
#All the unique values for ethncity
df['Suspect-ethnicity'].unique()
# Out:
# array(['Not Stated (NS)', 'White - White British (W1)',
#        'Black or Black British - Any other Black ethnic background (B9)',
#        'White - Any other White ethnic background (W9)',
#        'Black or Black British - Caribbean (B1)', nan,
#        'Asian or Asian British - Pakistani (A2)',
#        'Black or Black British - African (B2)'], dtype=object)

# %%
#Gives a count of all the unique values in the series, indexed form the dataframe by column.
df['Suspect-ethnicity'].value_counts()
# Out:
# White - White British (W1)                                         26
# Black or Black British - Caribbean (B1)                             4
# Not Stated (NS)                                                     2
# White - Any other White ethnic background (W9)                      2
# Asian or Asian British - Pakistani (A2)                             2
# Black or Black British - Any other Black ethnic background (B9)     1
# Black or Black British - African (B2)                               1
# Name: Suspect-ethnicity, dtype: int64

# %%
#Fancy indexing... This will return a dataframe
df[['Suspect-ethnicity', 'Officer-ethnicity']]
# Out:
#                                     Suspect-ethnicity Officer-ethnicity
# 0                                     Not Stated (NS)             Asian
# 1                                     Not Stated (NS)             Black
# 2                          White - White British (W1)             White
# 3                          White - White British (W1)             White
# 4   Black or Black British - Any other Black ethni...             Black
# 5                          White - White British (W1)             White
# 6      White - Any other White ethnic background (W9)               NaN
# 7             Black or Black British - Caribbean (B1)             Black
# 8                          White - White British (W1)             White
# 9                          White - White British (W1)             White
# 10                         White - White British (W1)             White
# 11                         White - White British (W1)             White
# 12                         White - White British (W1)             White
# 13                         White - White British (W1)             White
# 14                         White - White British (W1)             White
# 15                         White - White British (W1)             White
# 16                         White - White British (W1)             White
# 17                         White - White British (W1)             White
# 18                         White - White British (W1)             White
# 19                         White - White British (W1)             White
# 20                         White - White British (W1)             White
# 21            Black or Black British - Caribbean (B1)             Black
# 22                                                NaN             Asian
# 23            Asian or Asian British - Pakistani (A2)             Asian
# 24            Black or Black British - Caribbean (B1)             Black
# 25                         White - White British (W1)             White
# 26                         White - White British (W1)             White
# 27     White - Any other White ethnic background (W9)             White
# 28                         White - White British (W1)             White
# 29                         White - White British (W1)             White
# 30                                                NaN               NaN
# 31              Black or Black British - African (B2)             Black
# 32                         White - White British (W1)             White
# 33            Asian or Asian British - Pakistani (A2)             Asian
# 34                         White - White British (W1)             White
# 35                         White - White British (W1)             White
# 36                         White - White British (W1)             White
# 37                         White - White British (W1)             White
# 38                         White - White British (W1)             White
# 39            Black or Black British - Caribbean (B1)             Black

# %%
#If we want a specific index, we will have to use the method ix()
df.ix[4]
# Out:
# Gender                                                            Male
# Age                                                              10-17
# Suspect-ethnicity    Black or Black British - Any other Black ethni...
# Officer-ethnicity                                                Black
# Object-of-search                                          Stolen goods
# Outcome                              Nothing found - no further action
# Name: 4, dtype: object

# %%
df[df['Officer-ethnicity'] == 'Black']
# Out:
#    Gender      Age                                  Suspect-ethnicity  \
# 1    Male    18-24                                    Not Stated (NS)
# 4    Male    10-17  Black or Black British - Any other Black ethni...
# 7    Male  over 34            Black or Black British - Caribbean (B1)
# 21   Male    10-17            Black or Black British - Caribbean (B1)
# 24   Male    18-24            Black or Black British - Caribbean (B1)
# 31   Male    18-24              Black or Black British - African (B2)
# 39   Male  over 34            Black or Black British - Caribbean (B1)
#
#    Officer-ethnicity   Object-of-search  \
# 1              Black   Controlled drugs
# 4              Black       Stolen goods
# 7              Black   Controlled drugs
# 21             Black  Offensive weapons
# 24             Black   Controlled drugs
# 31             Black   Controlled drugs
# 39             Black       Stolen goods
#
#                                          Outcome
# 1              Nothing found - no further action
# 4              Nothing found - no further action
# 7   Article found - Detailed outcome unavailable
# 21             Nothing found - no further action
# 24  Article found - Detailed outcome unavailable
# 31             Nothing found - no further action
# 39             Nothing found - no further action

# %%
df[(df['Officer-ethnicity'] == 'Black') & (df['Object-of-search'] == 'Stolen goods')]
# Out:
#    Gender      Age                                  Suspect-ethnicity  \
# 4    Male    10-17  Black or Black British - Any other Black ethni...
# 39   Male  over 34            Black or Black British - Caribbean (B1)
#
#    Officer-ethnicity Object-of-search                            Outcome
# 4              Black     Stolen goods  Nothing found - no further action
# 39             Black     Stolen goods  Nothing found - no further action

# %%
#Now, we will hardly ever do this but in case.. we do the following to access one piece of data
df['Gender'][4]
# Out:
# 'Male'

# %%
#Or we can do the following...
df.ix[4,'Gender']
# Out:
# 'Male'

# %% [markdown]
# <h1>Our Turn</h1>
#
# <p>How many times was the officer looking for stolen goods?</p>

# %%
len(df[df['Object-of-search'] == 'Stolen goods'])
# Out:
# 13

# %% [markdown]
# <h2>Wasn't that fun?....</h2>
#
# <p>Now some stuff to do with dropping</p>

# %%
df.drop(2, inplace = True)

# %%
df[0:5]
# Out:
#   Gender    Age                                  Suspect-ethnicity  \
# 0   Male  18-24                                    Not Stated (NS)
# 1   Male  18-24                                    Not Stated (NS)
# 3   Male  10-17                         White - White British (W1)
# 4   Male  10-17  Black or Black British - Any other Black ethni...
# 5   Male  10-17                         White - White British (W1)
#
#   Officer-ethnicity  Object-of-search                            Outcome
# 0             Asian  Controlled drugs  Nothing found - no further action
# 1             Black  Controlled drugs  Nothing found - no further action
# 3             White      Stolen goods  Nothing found - no further action
# 4             Black      Stolen goods  Nothing found - no further action
# 5             White      Stolen goods  Nothing found - no further action

# %%
#... See, row 2 is gone, but as before we will reset the indexing.
df.reset_index(drop=True, inplace=True)
df[0:5]
# Out:
#   Gender    Age                                  Suspect-ethnicity  \
# 0   Male  18-24                                    Not Stated (NS)
# 1   Male  18-24                                    Not Stated (NS)
# 2   Male  10-17                         White - White British (W1)
# 3   Male  10-17  Black or Black British - Any other Black ethni...
# 4   Male  10-17                         White - White British (W1)
#
#   Officer-ethnicity  Object-of-search                            Outcome
# 0             Asian  Controlled drugs  Nothing found - no further action
# 1             Black  Controlled drugs  Nothing found - no further action
# 2             White      Stolen goods  Nothing found - no further action
# 3             Black      Stolen goods  Nothing found - no further action
# 4             White      Stolen goods  Nothing found - no further action

# %%
#The most likely thing we will want to do is delete using Boolean indexing BUT we are not allwed. Which is shit.
#So we will use our boolean index, get the rows we want to keep and store it back in the variable.
#It's like a really sneaky delete... Sneaky

df = (df[df['Suspect-ethnicity'] != 'Not Stated(NS)']).copy()
df.reset_index(drop = True,inplace = True)

# %%
df
# Out:
#     Gender      Age                                  Suspect-ethnicity  \
# 0     Male    18-24                                    Not Stated (NS)
# 1     Male    18-24                                    Not Stated (NS)
# 2     Male    10-17                         White - White British (W1)
# 3     Male    10-17  Black or Black British - Any other Black ethni...
# 4     Male    10-17                         White - White British (W1)
# 5     Male    18-24     White - Any other White ethnic background (W9)
# 6     Male  over 34            Black or Black British - Caribbean (B1)
# 7     Male    18-24                         White - White British (W1)
# 8     Male    18-24                         White - White British (W1)
# 9     Male    10-17                         White - White British (W1)
# 10    Male  over 34                         White - White British (W1)
# 11    Male    10-17                         White - White British (W1)
# 12    Male    10-17                         White - White British (W1)
# 13    Male    10-17                         White - White British (W1)
# 14    Male    10-17                         White - White British (W1)
# 15    Male    10-17                         White - White British (W1)
# 16    Male    25-34                         White - White British (W1)
# 17    Male    10-17                         White - White British (W1)
# 18  Female  over 34                         White - White British (W1)
# 19    Male    25-34                         White - White British (W1)
# 20    Male    10-17            Black or Black British - Caribbean (B1)
# 21    Male    10-17                                                NaN
# 22    Male    25-34            Asian or Asian British - Pakistani (A2)
# 23    Male    18-24            Black or Black British - Caribbean (B1)
# 24    Male    18-24                         White - White British (W1)
# 25    Male    18-24                         White - White British (W1)
# 26    Male    18-24     White - Any other White ethnic background (W9)
# 27    Male    18-24                         White - White British (W1)
# 28    Male    18-24                         White - White British (W1)
# 29    Male    25-34                                                NaN
# 30    Male    18-24              Black or Black British - African (B2)
# 31    Male    18-24                         White - White British (W1)
# 32    Male    18-24            Asian or Asian British - Pakistani (A2)
# 33    Male    25-34                         White - White British (W1)
# 34    Male  over 34                         White - White British (W1)
# 35    Male    18-24                         White - White British (W1)
# 36    Male    10-17                         White - White British (W1)
# 37    Male  over 34                         White - White British (W1)
# 38    Male  over 34            Black or Black British - Caribbean (B1)
#
#    Officer-ethnicity          Object-of-search  \
# 0              Asian          Controlled drugs
# 1              Black          Controlled drugs
# 2              White              Stolen goods
# 3              Black              Stolen goods
# 4              White              Stolen goods
# 5                NaN              Stolen goods
# 6              Black          Controlled drugs
# 7              White              Stolen goods
# 8              White  Article for use in theft
# 9              White         Offensive weapons
# 10             White          Controlled drugs
# 11             White          Controlled drugs
# 12             White          Controlled drugs
# 13             White          Controlled drugs
# 14             White              Stolen goods
# 15             White              Stolen goods
# 16             White          Controlled drugs
# 17             White          Controlled drugs
# 18             White              Stolen goods
# 19             White              Stolen goods
# 20             Black         Offensive weapons
# 21             Asian         Offensive weapons
# 22             Asian          Controlled drugs
# 23             Black          Controlled drugs
# 24             White          Controlled drugs
# 25             White          Controlled drugs
# 26             White          Controlled drugs
# 27             White              Stolen goods
# 28             White         Offensive weapons
# 29               NaN          Controlled drugs
# 30             Black          Controlled drugs
# 31             White          Controlled drugs
# 32             Asian         Offensive weapons
# 33             White          Controlled drugs
# 34             White              Stolen goods
# 35             White          Controlled drugs
# 36             White          Controlled drugs
# 37             White          Controlled drugs
# 38             Black              Stolen goods
#
#                                          Outcome
# 0              Nothing found - no further action
# 1              Nothing found - no further action
# 2              Nothing found - no further action
# 3              Nothing found - no further action
# 4              Nothing found - no further action
# 5                               Suspect arrested
# 6   Article found - Detailed outcome unavailable
# 7                               Suspect arrested
# 8                               Suspect arrested
# 9              Nothing found - no further action
# 10             Nothing found - no further action
# 11             Nothing found - no further action
# 12             Nothing found - no further action
# 13             Nothing found - no further action
# 14             Nothing found - no further action
# 15             Nothing found - no further action
# 16  Article found - Detailed outcome unavailable
# 17                              Suspect arrested
# 18                              Suspect arrested
# 19                              Suspect arrested
# 20             Nothing found - no further action
# 21             Nothing found - no further action
# 22             Nothing found - no further action
# 23  Article found - Detailed outcome unavailable
# 24             Nothing found - no further action
# 25             Nothing found - no further action
# 26             Nothing found - no further action
# 27                              Suspect arrested
# 28             Nothing found - no further action
# 29             Nothing found - no further action
# 30             Nothing found - no further action
# 31             Nothing found - no further action
# 32             Nothing found - no further action
# 33  Article found - Detailed outcome unavailable
# 34             Nothing found - no further action
# 35             Nothing found - no further action
# 36       Offender given drugs possession warning
# 37             Nothing found - no further action
# 38             Nothing found - no further action

# %%
#Suppose we want to get rid of a column such as age...
df.drop('Age', axis = 1, inplace = True)

# %%
df
# Out:
#     Gender                                  Suspect-ethnicity  \
# 0     Male                                    Not Stated (NS)
# 1     Male                                    Not Stated (NS)
# 2     Male                         White - White British (W1)
# 3     Male  Black or Black British - Any other Black ethni...
# 4     Male                         White - White British (W1)
# 5     Male     White - Any other White ethnic background (W9)
# 6     Male            Black or Black British - Caribbean (B1)
# 7     Male                         White - White British (W1)
# 8     Male                         White - White British (W1)
# 9     Male                         White - White British (W1)
# 10    Male                         White - White British (W1)
# 11    Male                         White - White British (W1)
# 12    Male                         White - White British (W1)
# 13    Male                         White - White British (W1)
# 14    Male                         White - White British (W1)
# 15    Male                         White - White British (W1)
# 16    Male                         White - White British (W1)
# 17    Male                         White - White British (W1)
# 18  Female                         White - White British (W1)
# 19    Male                         White - White British (W1)
# 20    Male            Black or Black British - Caribbean (B1)
# 21    Male                                                NaN
# 22    Male            Asian or Asian British - Pakistani (A2)
# 23    Male            Black or Black British - Caribbean (B1)
# 24    Male                         White - White British (W1)
# 25    Male                         White - White British (W1)
# 26    Male     White - Any other White ethnic background (W9)
# 27    Male                         White - White British (W1)
# 28    Male                         White - White British (W1)
# 29    Male                                                NaN
# 30    Male              Black or Black British - African (B2)
# 31    Male                         White - White British (W1)
# 32    Male            Asian or Asian British - Pakistani (A2)
# 33    Male                         White - White British (W1)
# 34    Male                         White - White British (W1)
# 35    Male                         White - White British (W1)
# 36    Male                         White - White British (W1)
# 37    Male                         White - White British (W1)
# 38    Male            Black or Black British - Caribbean (B1)
#
#    Officer-ethnicity          Object-of-search  \
# 0              Asian          Controlled drugs
# 1              Black          Controlled drugs
# 2              White              Stolen goods
# 3              Black              Stolen goods
# 4              White              Stolen goods
# 5                NaN              Stolen goods
# 6              Black          Controlled drugs
# 7              White              Stolen goods
# 8              White  Article for use in theft
# 9              White         Offensive weapons
# 10             White          Controlled drugs
# 11             White          Controlled drugs
# 12             White          Controlled drugs
# 13             White          Controlled drugs
# 14             White              Stolen goods
# 15             White              Stolen goods
# 16             White          Controlled drugs
# 17             White          Controlled drugs
# 18             White              Stolen goods
# 19             White              Stolen goods
# 20             Black         Offensive weapons
# 21             Asian         Offensive weapons
# 22             Asian          Controlled drugs
# 23             Black          Controlled drugs
# 24             White          Controlled drugs
# 25             White          Controlled drugs
# 26             White          Controlled drugs
# 27             White              Stolen goods
# 28             White         Offensive weapons
# 29               NaN          Controlled drugs
# 30             Black          Controlled drugs
# 31             White          Controlled drugs
# 32             Asian         Offensive weapons
# 33             White          Controlled drugs
# 34             White              Stolen goods
# 35             White          Controlled drugs
# 36             White          Controlled drugs
# 37             White          Controlled drugs
# 38             Black              Stolen goods
#
#                                          Outcome
# 0              Nothing found - no further action
# 1              Nothing found - no further action
# 2              Nothing found - no further action
# 3              Nothing found - no further action
# 4              Nothing found - no further action
# 5                               Suspect arrested
# 6   Article found - Detailed outcome unavailable
# 7                               Suspect arrested
# 8                               Suspect arrested
# 9              Nothing found - no further action
# 10             Nothing found - no further action
# 11             Nothing found - no further action
# 12             Nothing found - no further action
# 13             Nothing found - no further action
# 14             Nothing found - no further action
# 15             Nothing found - no further action
# 16  Article found - Detailed outcome unavailable
# 17                              Suspect arrested
# 18                              Suspect arrested
# 19                              Suspect arrested
# 20             Nothing found - no further action
# 21             Nothing found - no further action
# 22             Nothing found - no further action
# 23  Article found - Detailed outcome unavailable
# 24             Nothing found - no further action
# 25             Nothing found - no further action
# 26             Nothing found - no further action
# 27                              Suspect arrested
# 28             Nothing found - no further action
# 29             Nothing found - no further action
# 30             Nothing found - no further action
# 31             Nothing found - no further action
# 32             Nothing found - no further action
# 33  Article found - Detailed outcome unavailable
# 34             Nothing found - no further action
# 35             Nothing found - no further action
# 36       Offender given drugs possession warning
# 37             Nothing found - no further action
# 38             Nothing found - no further action

# %%
#How do we insert a column... well, it's with insert... into the zero'th column
df.insert(0, 'Year', 2016)
#insert(column index, column name, broadcast initial value)

df
# Out:
#     Year  Gender                                  Suspect-ethnicity  \
# 0   2016    Male                                    Not Stated (NS)
# 1   2016    Male                                    Not Stated (NS)
# 2   2016    Male                         White - White British (W1)
# 3   2016    Male  Black or Black British - Any other Black ethni...
# 4   2016    Male                         White - White British (W1)
# 5   2016    Male     White - Any other White ethnic background (W9)
# 6   2016    Male            Black or Black British - Caribbean (B1)
# 7   2016    Male                         White - White British (W1)
# 8   2016    Male                         White - White British (W1)
# 9   2016    Male                         White - White British (W1)
# 10  2016    Male                         White - White British (W1)
# 11  2016    Male                         White - White British (W1)
# 12  2016    Male                         White - White British (W1)
# 13  2016    Male                         White - White British (W1)
# 14  2016    Male                         White - White British (W1)
# 15  2016    Male                         White - White British (W1)
# 16  2016    Male                         White - White British (W1)
# 17  2016    Male                         White - White British (W1)
# 18  2016  Female                         White - White British (W1)
# 19  2016    Male                         White - White British (W1)
# 20  2016    Male            Black or Black British - Caribbean (B1)
# 21  2016    Male                                                NaN
# 22  2016    Male            Asian or Asian British - Pakistani (A2)
# 23  2016    Male            Black or Black British - Caribbean (B1)
# 24  2016    Male                         White - White British (W1)
# 25  2016    Male                         White - White British (W1)
# 26  2016    Male     White - Any other White ethnic background (W9)
# 27  2016    Male                         White - White British (W1)
# 28  2016    Male                         White - White British (W1)
# 29  2016    Male                                                NaN
# 30  2016    Male              Black or Black British - African (B2)
# 31  2016    Male                         White - White British (W1)
# 32  2016    Male            Asian or Asian British - Pakistani (A2)
# 33  2016    Male                         White - White British (W1)
# 34  2016    Male                         White - White British (W1)
# 35  2016    Male                         White - White British (W1)
# 36  2016    Male                         White - White British (W1)
# 37  2016    Male                         White - White British (W1)
# 38  2016    Male            Black or Black British - Caribbean (B1)
#
#    Officer-ethnicity          Object-of-search  \
# 0              Asian          Controlled drugs
# 1              Black          Controlled drugs
# 2              White              Stolen goods
# 3              Black              Stolen goods
# 4              White              Stolen goods
# 5                NaN              Stolen goods
# 6              Black          Controlled drugs
# 7              White              Stolen goods
# 8              White  Article for use in theft
# 9              White         Offensive weapons
# 10             White          Controlled drugs
# 11             White          Controlled drugs
# 12             White          Controlled drugs
# 13             White          Controlled drugs
# 14             White              Stolen goods
# 15             White              Stolen goods
# 16             White          Controlled drugs
# 17             White          Controlled drugs
# 18             White              Stolen goods
# 19             White              Stolen goods
# 20             Black         Offensive weapons
# 21             Asian         Offensive weapons
# 22             Asian          Controlled drugs
# 23             Black          Controlled drugs
# 24             White          Controlled drugs
# 25             White          Controlled drugs
# 26             White          Controlled drugs
# 27             White              Stolen goods
# 28             White         Offensive weapons
# 29               NaN          Controlled drugs
# 30             Black          Controlled drugs
# 31             White          Controlled drugs
# 32             Asian         Offensive weapons
# 33             White          Controlled drugs
# 34             White              Stolen goods
# 35             White          Controlled drugs
# 36             White          Controlled drugs
# 37             White          Controlled drugs
# 38             Black              Stolen goods
#
#                                          Outcome
# 0              Nothing found - no further action
# 1              Nothing found - no further action
# 2              Nothing found - no further action
# 3              Nothing found - no further action
# 4              Nothing found - no further action
# 5                               Suspect arrested
# 6   Article found - Detailed outcome unavailable
# 7                               Suspect arrested
# 8                               Suspect arrested
# 9              Nothing found - no further action
# 10             Nothing found - no further action
# 11             Nothing found - no further action
# 12             Nothing found - no further action
# 13             Nothing found - no further action
# 14             Nothing found - no further action
# 15             Nothing found - no further action
# 16  Article found - Detailed outcome unavailable
# 17                              Suspect arrested
# 18                              Suspect arrested
# 19                              Suspect arrested
# 20             Nothing found - no further action
# 21             Nothing found - no further action
# 22             Nothing found - no further action
# 23  Article found - Detailed outcome unavailable
# 24             Nothing found - no further action
# 25             Nothing found - no further action
# 26             Nothing found - no further action
# 27                              Suspect arrested
# 28             Nothing found - no further action
# 29             Nothing found - no further action
# 30             Nothing found - no further action
# 31             Nothing found - no further action
# 32             Nothing found - no further action
# 33  Article found - Detailed outcome unavailable
# 34             Nothing found - no further action
# 35             Nothing found - no further action
# 36       Offender given drugs possession warning
# 37             Nothing found - no further action
# 38             Nothing found - no further action

# %%
#Suppose we have two dataframes, we can stick them into a single datastructure using concatenation. 
df1 = df[['Gender', 'Object-of-search']]
df2 = df[['Officer-ethnicity', 'Outcome']]

df3 = pd.concat([df1,df2], axis=1)
df3
# Out:
#     Gender          Object-of-search Officer-ethnicity  \
# 0     Male          Controlled drugs             Asian
# 1     Male          Controlled drugs             Black
# 2     Male              Stolen goods             White
# 3     Male              Stolen goods             Black
# 4     Male              Stolen goods             White
# 5     Male              Stolen goods               NaN
# 6     Male          Controlled drugs             Black
# 7     Male              Stolen goods             White
# 8     Male  Article for use in theft             White
# 9     Male         Offensive weapons             White
# 10    Male          Controlled drugs             White
# 11    Male          Controlled drugs             White
# 12    Male          Controlled drugs             White
# 13    Male          Controlled drugs             White
# 14    Male              Stolen goods             White
# 15    Male              Stolen goods             White
# 16    Male          Controlled drugs             White
# 17    Male          Controlled drugs             White
# 18  Female              Stolen goods             White
# 19    Male              Stolen goods             White
# 20    Male         Offensive weapons             Black
# 21    Male         Offensive weapons             Asian
# 22    Male          Controlled drugs             Asian
# 23    Male          Controlled drugs             Black
# 24    Male          Controlled drugs             White
# 25    Male          Controlled drugs             White
# 26    Male          Controlled drugs             White
# 27    Male              Stolen goods             White
# 28    Male         Offensive weapons             White
# 29    Male          Controlled drugs               NaN
# 30    Male          Controlled drugs             Black
# 31    Male          Controlled drugs             White
# 32    Male         Offensive weapons             Asian
# 33    Male          Controlled drugs             White
# 34    Male              Stolen goods             White
# 35    Male          Controlled drugs             White
# 36    Male          Controlled drugs             White
# 37    Male          Controlled drugs             White
# 38    Male              Stolen goods             Black
#
#                                          Outcome
# 0              Nothing found - no further action
# 1              Nothing found - no further action
# 2              Nothing found - no further action
# 3              Nothing found - no further action
# 4              Nothing found - no further action
# 5                               Suspect arrested
# 6   Article found - Detailed outcome unavailable
# 7                               Suspect arrested
# 8                               Suspect arrested
# 9              Nothing found - no further action
# 10             Nothing found - no further action
# 11             Nothing found - no further action
# 12             Nothing found - no further action
# 13             Nothing found - no further action
# 14             Nothing found - no further action
# 15             Nothing found - no further action
# 16  Article found - Detailed outcome unavailable
# 17                              Suspect arrested
# 18                              Suspect arrested
# 19                              Suspect arrested
# 20             Nothing found - no further action
# 21             Nothing found - no further action
# 22             Nothing found - no further action
# 23  Article found - Detailed outcome unavailable
# 24             Nothing found - no further action
# 25             Nothing found - no further action
# 26             Nothing found - no further action
# 27                              Suspect arrested
# 28             Nothing found - no further action
# 29             Nothing found - no further action
# 30             Nothing found - no further action
# 31             Nothing found - no further action
# 32             Nothing found - no further action
# 33  Article found - Detailed outcome unavailable
# 34             Nothing found - no further action
# 35             Nothing found - no further action
# 36       Offender given drugs possession warning
# 37             Nothing found - no further action
# 38             Nothing found - no further action

# %%
#For when we want to replace (obviously)... This will take in a dictionary
df.replace({'Officer-ethnicity' : {'Asian' : 0, 'Black'  : 1, 'White' : 2}, 
            'Object-of-search' : {'Stolen goods' : 'SG', 'Controlled drugs' : 'CD'}})
# Out:
#     Year  Gender                                  Suspect-ethnicity  \
# 0   2016    Male                                    Not Stated (NS)
# 1   2016    Male                                    Not Stated (NS)
# 2   2016    Male                         White - White British (W1)
# 3   2016    Male  Black or Black British - Any other Black ethni...
# 4   2016    Male                         White - White British (W1)
# 5   2016    Male     White - Any other White ethnic background (W9)
# 6   2016    Male            Black or Black British - Caribbean (B1)
# 7   2016    Male                         White - White British (W1)
# 8   2016    Male                         White - White British (W1)
# 9   2016    Male                         White - White British (W1)
# 10  2016    Male                         White - White British (W1)
# 11  2016    Male                         White - White British (W1)
# 12  2016    Male                         White - White British (W1)
# 13  2016    Male                         White - White British (W1)
# 14  2016    Male                         White - White British (W1)
# 15  2016    Male                         White - White British (W1)
# 16  2016    Male                         White - White British (W1)
# 17  2016    Male                         White - White British (W1)
# 18  2016  Female                         White - White British (W1)
# 19  2016    Male                         White - White British (W1)
# 20  2016    Male            Black or Black British - Caribbean (B1)
# 21  2016    Male                                                NaN
# 22  2016    Male            Asian or Asian British - Pakistani (A2)
# 23  2016    Male            Black or Black British - Caribbean (B1)
# 24  2016    Male                         White - White British (W1)
# 25  2016    Male                         White - White British (W1)
# 26  2016    Male     White - Any other White ethnic background (W9)
# 27  2016    Male                         White - White British (W1)
# 28  2016    Male                         White - White British (W1)
# 29  2016    Male                                                NaN
# 30  2016    Male              Black or Black British - African (B2)
# 31  2016    Male                         White - White British (W1)
# 32  2016    Male            Asian or Asian British - Pakistani (A2)
# 33  2016    Male                         White - White British (W1)
# 34  2016    Male                         White - White British (W1)
# 35  2016    Male                         White - White British (W1)
# 36  2016    Male                         White - White British (W1)
# 37  2016    Male                         White - White British (W1)
# 38  2016    Male            Black or Black British - Caribbean (B1)
#
#     Officer-ethnicity          Object-of-search  \
# 0                 0.0                        CD
# 1                 1.0                        CD
# 2                 2.0                        SG
# 3                 1.0                        SG
# 4                 2.0                        SG
# 5                 NaN                        SG
# 6                 1.0                        CD
# 7                 2.0                        SG
# 8                 2.0  Article for use in theft
# 9                 2.0         Offensive weapons
# 10                2.0                        CD
# 11                2.0                        CD
# 12                2.0                        CD
# 13                2.0                        CD
# 14                2.0                        SG
# 15                2.0                        SG
# 16                2.0                        CD
# 17                2.0                        CD
# 18                2.0                        SG
# 19                2.0                        SG
# 20                1.0         Offensive weapons
# 21                0.0         Offensive weapons
# 22                0.0                        CD
# 23                1.0                        CD
# 24                2.0                        CD
# 25                2.0                        CD
# 26                2.0                        CD
# 27                2.0                        SG
# 28                2.0         Offensive weapons
# 29                NaN                        CD
# 30                1.0                        CD
# 31                2.0                        CD
# 32                0.0         Offensive weapons
# 33                2.0                        CD
# 34                2.0                        SG
# 35                2.0                        CD
# 36                2.0                        CD
# 37                2.0                        CD
# 38                1.0                        SG
#
#                                          Outcome
# 0              Nothing found - no further action
# 1              Nothing found - no further action
# 2              Nothing found - no further action
# 3              Nothing found - no further action
# 4              Nothing found - no further action
# 5                               Suspect arrested
# 6   Article found - Detailed outcome unavailable
# 7                               Suspect arrested
# 8                               Suspect arrested
# 9              Nothing found - no further action
# 10             Nothing found - no further action
# 11             Nothing found - no further action
# 12             Nothing found - no further action
# 13             Nothing found - no further action
# 14             Nothing found - no further action
# 15             Nothing found - no further action
# 16  Article found - Detailed outcome unavailable
# 17                              Suspect arrested
# 18                              Suspect arrested
# 19                              Suspect arrested
# 20             Nothing found - no further action
# 21             Nothing found - no further action
# 22             Nothing found - no further action
# 23  Article found - Detailed outcome unavailable
# 24             Nothing found - no further action
# 25             Nothing found - no further action
# 26             Nothing found - no further action
# 27                              Suspect arrested
# 28             Nothing found - no further action
# 29             Nothing found - no further action
# 30             Nothing found - no further action
# 31             Nothing found - no further action
# 32             Nothing found - no further action
# 33  Article found - Detailed outcome unavailable
# 34             Nothing found - no further action
# 35             Nothing found - no further action
# 36       Offender given drugs possession warning
# 37             Nothing found - no further action
# 38             Nothing found - no further action

# %%
#Let's read back in our dataframe because we've entirely fucked it up...

df = pd.read_csv('dataset-stop-and-searchA.csv')

# %%
#Now we'll have to have a look at shuffling the data, for machine learning we will need  to have unsorted data.
m, n = df.shape
m
# Out:
# 40

# %%
#We won't be using this in numpy but for now we will just for the example... 
#This will give a random order of m numbers
np.random.permutation(m)
# Out:
# array([ 2, 39, 26, 19, 28, 37, 34, 31, 11,  7, 30,  6, 27, 21,  0, 10, 38,
#        29, 33, 25, 12,  5,  1, 16, 36, 17, 18, 32,  8, 23,  9, 13, 15,  3,
#        20, 22,  4, 24, 14, 35])

# %%
df = df.take(np.random.permutation(df.shape[0]))
df.reset_index(drop=True, inplace=True)

# %%
#Now we will have a sconce at som emissing values, in your CSV file if we have a gap there is data missing
#That will be represented as ,, in the csv file
#When this is represented in a dataframe it will be NaN

df = pd.read_csv('dataset-stop-and-searchA.csv')
df.dropna(inplace=True, axis=0)

# %%
df = pd.read_csv('dataset-stop-and-searchA.csv')
df.dropna(inplace=True, subset=['Gender', 'Officer-ethnicity'], axis = 0)

# %%
df = pd.read_csv('dataset-stop-and-searchA.csv')
df.dropna(inplace=True, axis = 1)

# %%
#For replacing NaNs with something else.
df = pd.read_csv('dataset-stop-and-searchA.csv')
df.fillna('Unknown')
# Out:
#     Gender      Age                                  Suspect-ethnicity  \
# 0     Male    18-24                                    Not Stated (NS)
# 1     Male    18-24                                    Not Stated (NS)
# 2     Male    10-17                         White - White British (W1)
# 3     Male    10-17                         White - White British (W1)
# 4     Male    10-17  Black or Black British - Any other Black ethni...
# 5     Male    10-17                         White - White British (W1)
# 6     Male    18-24     White - Any other White ethnic background (W9)
# 7     Male  over 34            Black or Black British - Caribbean (B1)
# 8     Male    18-24                         White - White British (W1)
# 9     Male    18-24                         White - White British (W1)
# 10    Male    10-17                         White - White British (W1)
# 11    Male  over 34                         White - White British (W1)
# 12    Male    10-17                         White - White British (W1)
# 13    Male    10-17                         White - White British (W1)
# 14    Male    10-17                         White - White British (W1)
# 15    Male    10-17                         White - White British (W1)
# 16    Male    10-17                         White - White British (W1)
# 17    Male    25-34                         White - White British (W1)
# 18    Male    10-17                         White - White British (W1)
# 19  Female  over 34                         White - White British (W1)
# 20    Male    25-34                         White - White British (W1)
# 21    Male    10-17            Black or Black British - Caribbean (B1)
# 22    Male    10-17                                            Unknown
# 23    Male    25-34            Asian or Asian British - Pakistani (A2)
# 24    Male    18-24            Black or Black British - Caribbean (B1)
# 25    Male    18-24                         White - White British (W1)
# 26    Male    18-24                         White - White British (W1)
# 27    Male    18-24     White - Any other White ethnic background (W9)
# 28    Male    18-24                         White - White British (W1)
# 29    Male    18-24                         White - White British (W1)
# 30    Male    25-34                                            Unknown
# 31    Male    18-24              Black or Black British - African (B2)
# 32    Male    18-24                         White - White British (W1)
# 33    Male    18-24            Asian or Asian British - Pakistani (A2)
# 34    Male    25-34                         White - White British (W1)
# 35    Male  over 34                         White - White British (W1)
# 36    Male    18-24                         White - White British (W1)
# 37    Male    10-17                         White - White British (W1)
# 38    Male  over 34                         White - White British (W1)
# 39    Male  over 34            Black or Black British - Caribbean (B1)
#
#    Officer-ethnicity          Object-of-search  \
# 0              Asian          Controlled drugs
# 1              Black          Controlled drugs
# 2              White              Stolen goods
# 3              White              Stolen goods
# 4              Black              Stolen goods
# 5              White              Stolen goods
# 6            Unknown              Stolen goods
# 7              Black          Controlled drugs
# 8              White              Stolen goods
# 9              White  Article for use in theft
# 10             White         Offensive weapons
# 11             White          Controlled drugs
# 12             White          Controlled drugs
# 13             White          Controlled drugs
# 14             White          Controlled drugs
# 15             White              Stolen goods
# 16             White              Stolen goods
# 17             White          Controlled drugs
# 18             White          Controlled drugs
# 19             White              Stolen goods
# 20             White              Stolen goods
# 21             Black         Offensive weapons
# 22             Asian         Offensive weapons
# 23             Asian          Controlled drugs
# 24             Black          Controlled drugs
# 25             White          Controlled drugs
# 26             White          Controlled drugs
# 27             White          Controlled drugs
# 28             White              Stolen goods
# 29             White         Offensive weapons
# 30           Unknown          Controlled drugs
# 31             Black          Controlled drugs
# 32             White          Controlled drugs
# 33             Asian         Offensive weapons
# 34             White          Controlled drugs
# 35             White              Stolen goods
# 36             White          Controlled drugs
# 37             White          Controlled drugs
# 38             White          Controlled drugs
# 39             Black              Stolen goods
#
#                                          Outcome
# 0              Nothing found - no further action
# 1              Nothing found - no further action
# 2              Nothing found - no further action
# 3              Nothing found - no further action
# 4              Nothing found - no further action
# 5              Nothing found - no further action
# 6                               Suspect arrested
# 7   Article found - Detailed outcome unavailable
# 8                               Suspect arrested
# 9                               Suspect arrested
# 10             Nothing found - no further action
# 11             Nothing found - no further action
# 12             Nothing found - no further action
# 13             Nothing found - no further action
# 14             Nothing found - no further action
# 15             Nothing found - no further action
# 16             Nothing found - no further action
# 17  Article found - Detailed outcome unavailable
# 18                              Suspect arrested
# 19                              Suspect arrested
# 20                              Suspect arrested
# 21             Nothing found - no further action
# 22             Nothing found - no further action
# 23             Nothing found - no further action
# 24  Article found - Detailed outcome unavailable
# 25             Nothing found - no further action
# 26             Nothing found - no further action
# 27             Nothing found - no further action
# 28                              Suspect arrested
# 29             Nothing found - no further action
# 30             Nothing found - no further action
# 31             Nothing found - no further action
# 32             Nothing found - no further action
# 33             Nothing found - no further action
# 34  Article found - Detailed outcome unavailable
# 35             Nothing found - no further action
# 36             Nothing found - no further action
# 37       Offender given drugs possession warning
# 38             Nothing found - no further action
# 39             Nothing found - no further action

# %%
df = pd.read_csv('dataset-stop-and-searchA.csv')
df.fillna({'Suspect-ethnicity' : -1, 'Officer-ethnicity' : -2})
# Out:
#     Gender      Age                                  Suspect-ethnicity  \
# 0     Male    18-24                                    Not Stated (NS)
# 1     Male    18-24                                    Not Stated (NS)
# 2     Male    10-17                         White - White British (W1)
# 3     Male    10-17                         White - White British (W1)
# 4     Male    10-17  Black or Black British - Any other Black ethni...
# 5     Male    10-17                         White - White British (W1)
# 6     Male    18-24     White - Any other White ethnic background (W9)
# 7     Male  over 34            Black or Black British - Caribbean (B1)
# 8     Male    18-24                         White - White British (W1)
# 9     Male    18-24                         White - White British (W1)
# 10    Male    10-17                         White - White British (W1)
# 11    Male  over 34                         White - White British (W1)
# 12    Male    10-17                         White - White British (W1)
# 13    Male    10-17                         White - White British (W1)
# 14    Male    10-17                         White - White British (W1)
# 15    Male    10-17                         White - White British (W1)
# 16    Male    10-17                         White - White British (W1)
# 17    Male    25-34                         White - White British (W1)
# 18    Male    10-17                         White - White British (W1)
# 19  Female  over 34                         White - White British (W1)
# 20    Male    25-34                         White - White British (W1)
# 21    Male    10-17            Black or Black British - Caribbean (B1)
# 22    Male    10-17                                                 -1
# 23    Male    25-34            Asian or Asian British - Pakistani (A2)
# 24    Male    18-24            Black or Black British - Caribbean (B1)
# 25    Male    18-24                         White - White British (W1)
# 26    Male    18-24                         White - White British (W1)
# 27    Male    18-24     White - Any other White ethnic background (W9)
# 28    Male    18-24                         White - White British (W1)
# 29    Male    18-24                         White - White British (W1)
# 30    Male    25-34                                                 -1
# 31    Male    18-24              Black or Black British - African (B2)
# 32    Male    18-24                         White - White British (W1)
# 33    Male    18-24            Asian or Asian British - Pakistani (A2)
# 34    Male    25-34                         White - White British (W1)
# 35    Male  over 34                         White - White British (W1)
# 36    Male    18-24                         White - White British (W1)
# 37    Male    10-17                         White - White British (W1)
# 38    Male  over 34                         White - White British (W1)
# 39    Male  over 34            Black or Black British - Caribbean (B1)
#
#    Officer-ethnicity          Object-of-search  \
# 0              Asian          Controlled drugs
# 1              Black          Controlled drugs
# 2              White              Stolen goods
# 3              White              Stolen goods
# 4              Black              Stolen goods
# 5              White              Stolen goods
# 6                 -2              Stolen goods
# 7              Black          Controlled drugs
# 8              White              Stolen goods
# 9              White  Article for use in theft
# 10             White         Offensive weapons
# 11             White          Controlled drugs
# 12             White          Controlled drugs
# 13             White          Controlled drugs
# 14             White          Controlled drugs
# 15             White              Stolen goods
# 16             White              Stolen goods
# 17             White          Controlled drugs
# 18             White          Controlled drugs
# 19             White              Stolen goods
# 20             White              Stolen goods
# 21             Black         Offensive weapons
# 22             Asian         Offensive weapons
# 23             Asian          Controlled drugs
# 24             Black          Controlled drugs
# 25             White          Controlled drugs
# 26             White          Controlled drugs
# 27             White          Controlled drugs
# 28             White              Stolen goods
# 29             White         Offensive weapons
# 30                -2          Controlled drugs
# 31             Black          Controlled drugs
# 32             White          Controlled drugs
# 33             Asian         Offensive weapons
# 34             White          Controlled drugs
# 35             White              Stolen goods
# 36             White          Controlled drugs
# 37             White          Controlled drugs
# 38             White          Controlled drugs
# 39             Black              Stolen goods
#
#                                          Outcome
# 0              Nothing found - no further action
# 1              Nothing found - no further action
# 2              Nothing found - no further action
# 3              Nothing found - no further action
# 4              Nothing found - no further action
# 5              Nothing found - no further action
# 6                               Suspect arrested
# 7   Article found - Detailed outcome unavailable
# 8                               Suspect arrested
# 9                               Suspect arrested
# 10             Nothing found - no further action
# 11             Nothing found - no further action
# 12             Nothing found - no further action
# 13             Nothing found - no further action
# 14             Nothing found - no further action
# 15             Nothing found - no further action
# 16             Nothing found - no further action
# 17  Article found - Detailed outcome unavailable
# 18                              Suspect arrested
# 19                              Suspect arrested
# 20                              Suspect arrested
# 21             Nothing found - no further action
# 22             Nothing found - no further action
# 23             Nothing found - no further action
# 24  Article found - Detailed outcome unavailable
# 25             Nothing found - no further action
# 26             Nothing found - no further action
# 27             Nothing found - no further action
# 28                              Suspect arrested
# 29             Nothing found - no further action
# 30             Nothing found - no further action
# 31             Nothing found - no further action
# 32             Nothing found - no further action
# 33             Nothing found - no further action
# 34  Article found - Detailed outcome unavailable
# 35             Nothing found - no further action
# 36             Nothing found - no further action
# 37       Offender given drugs possession warning
# 38             Nothing found - no further action
# 39             Nothing found - no further action

# %% [markdown]
# <h1>Exercise</h1>

# %%
df = pd.read_csv('dataset-stop-and-searchB.csv')

# %% [markdown]
# <p>Are the Thames Valley police racist?</p>

# %%
df['Suspect-ethnicity'].unique()
# Out:
# array(['White - White British (W1)',
#        'Black or Black British - Caribbean (B1)', 'Not Stated (NS)',
#        'Asian or Asian British - Indian (A1)',
#        'White - Any other White ethnic background (W9)', nan,
#        'Black or Black British - African (B2)',
#        'Mixed - White and Asian (M3)',
#        'Mixed - Any other Mixed ethnic background (M9)',
#        'Asian or Asian British - Pakistani (A2)',
#        'Mixed - White and Black Caribbean (M1)',
#        'Chinese or other ethnic group - Chinese (O1)',
#        'Black or Black British - Any other Black ethnic background (B9)',
#        'Asian or Asian British - Any other Asian ethnic background (A9)',
#        'Mixed - White and Black African (M2)',
#        'Chinese or other ethnic group - Any other ethnic group (O9)',
#        'White - White Irish (W2)',
#        'Asian or Asian British - Bangladeshi (A3)'], dtype=object)

# %%
df.replace({'Suspect-ethnicity' : {'White - White British (W1)' : 'White',
       'Black or Black British - Caribbean (B1)', 'Not Stated (NS)': 'Black',
       'Asian or Asian British - Indian (A1)',
       'White - Any other White ethnic background (W9)' : 'White',
       'Black or Black British - African (B2)',
       'Mixed - White and Asian (M3)',
       'Mixed - Any other Mixed ethnic background (M9)',
       'Asian or Asian British - Pakistani (A2)',
       'Mixed - White and Black Caribbean (M1)',
       'Chinese or other ethnic group - Chinese (O1)',
       'Black or Black British - Any other Black ethnic background (B9)',
       'Asian or Asian British - Any other Asian ethnic background (A9)',
       'Mixed - White and Black African (M2)',
       'Chinese or other ethnic group - Any other ethnic group (O9)',
       'White - White Irish (W2)': 'White',
       'Asian or Asian British - Bangladeshi (A3)'}
            })

df.dropna(inplace=True, subset=['Suspect-ethnicity', 'Officer-ethnicity'], axis = 0)

smallerdf = df[(df['Officer-ethnicity'].str.contains(df['Suspect-ethnicity'].str, na = False))
          & (df['Outcome'] != 'Nothing found - no further action')]

m = len(smallerdf)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-279-468f893d48dc> in <module>()
# ----> 1 smallerdf = df[(df['Officer-ethnicity'].str.contains(df['Suspect-ethnicity'].str, na = False))
#       2           & (df['Outcome'] != 'Nothing found - no further action')]
#       3
#       4 m = len(smallerdf)
#
# /usr/local/lib/python3.4/dist-packages/pandas/core/strings.py in contains(self, pat, case, flags, na, regex)
#    1492     def contains(self, pat, case=True, flags=0, na=np.nan, regex=True):
#    1493         result = str_contains(self._data, pat, case=case, flags=flags, na=na,
# -> 1494                               regex=regex)
#    1495         return self._wrap_result(result)
#    1496
#
# /usr/local/lib/python3.4/dist-packages/pandas/core/strings.py in str_contains(arr, pat, case, flags, na, regex)
#     235             flags |= re.IGNORECASE
#     236
# --> 237         regex = re.compile(pat, flags=flags)
#     238
#     239         if regex.groups > 0:
#
# /usr/lib/python3.4/re.py in compile(pattern, flags)
#     217 def compile(pattern, flags=0):
#     218     "Compile a regular expression pattern, returning a pattern object."
# --> 219     return _compile(pattern, flags)
#     220
#     221 def purge():
#
# /usr/lib/python3.4/re.py in _compile(pattern, flags)
#     285         return pattern
#     286     if not sre_compile.isstring(pattern):
# --> 287         raise TypeError("first argument must be string or compiled pattern")
#     288     p = sre_compile.compile(pattern, flags)
#     289     if not bypass_cache:
#
# TypeError: first argument must be string or compiled pattern
